# %% [markdown]
# Pandas 19 - Formatting tampilan Data Frame
# Import Modules

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.0

# %% [markdown]
# Persiapan Data Frame

# %%
n_rows = 5
n_cols = 2
cols = ['omset', 'operasional']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    omset  operasional
# 0      9           16
# 1     10            8
# 2     16           19
# 3      6            1
# 4     14            1

# %%
df['omset'] = df['omset'] * 100_000
df['operasional'] = df['operasional'] * 10_000
df
# Out:
#      omset  operasional
# 0   900000       160000
# 1  1000000        80000
# 2  1600000       190000
# 3   600000        10000
# 4  1400000        10000

# %%
# Menambahkan kolom 'tanggal'
start_date = pd.to_datetime('2000-01-01')
df['tanggal'] = pd.date_range(start=start_date, periods=n_rows)

# Reorder columns to match the desired order
df = df[['tanggal', 'omset', 'operasional']]

# Display the DataFrame
df
# Out:
#      tanggal    omset  operasional
# 0 2000-01-01   900000       160000
# 1 2000-01-02  1000000        80000
# 2 2000-01-03  1600000       190000
# 3 2000-01-04   600000        10000
# 4 2000-01-05  1400000        10000

# %% [markdown]
# Melakukan formatting tampilan Data Frame

# %%
# Format yang akan digunakan untuk menampilkan DataFrame
formatku = {'tanggal': '{:%d/%m/%y}', 'operasional': 'Rp {:.2f}', 'omset': 'Rp {:.2f}'}

# Membuat objek Styler untuk DataFrame dengan format yang ditentukan
laporan = df.style.format(formatku)

# Menampilkan objek Styler, bukan objek DataFrame
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_f35c4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f35c4_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_f35c4_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_f35c4_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f35c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f35c4_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_f35c4_row0_col1" class="data row0 col1" >Rp 900000.00</td>
#       <td id="T_f35c4_row0_col2" class="data row0 col2" >Rp 160000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f35c4_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_f35c4_row1_col1" class="data row1 col1" >Rp 1000000.00</td>
#       <td id="T_f35c4_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f35c4_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_f35c4_row2_col1" class="data row2 col1" >Rp 1600000.00</td>
#       <td id="T_f35c4_row2_col2" class="data row2 col2" >Rp 190000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f35c4_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_f35c4_row3_col1" class="data row3 col1" >Rp 600000.00</td>
#       <td id="T_f35c4_row3_col2" class="data row3 col2" >Rp 10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f35c4_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_f35c4_row4_col1" class="data row4 col1" >Rp 1400000.00</td>
#       <td id="T_f35c4_row4_col2" class="data row4 col2" >Rp 10000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menampilkan tipe data dari objek Styler
type(laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
# Membuat salinan DataFrame dan mengganti indeksnya dengan string kosong
df_temp = df.copy()
df_temp.index = [''] * len(df)

# Membuat objek Styler dengan format yang telah ditentukan
df_temp_styled = df_temp.style.format(formatku)

# Menampilkan tampilan yang diformat menggunakan Styler
df_temp_styled
# Out:
# <style type="text/css">
# </style>
# <table id="T_b4f1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4f1e_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_b4f1e_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_b4f1e_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4f1e_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_b4f1e_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_b4f1e_row0_col1" class="data row0 col1" >Rp 900000.00</td>
#       <td id="T_b4f1e_row0_col2" class="data row0 col2" >Rp 160000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b4f1e_level0_row1" class="row_heading level0 row1" ></th>
#       <td id="T_b4f1e_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_b4f1e_row1_col1" class="data row1 col1" >Rp 1000000.00</td>
#       <td id="T_b4f1e_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b4f1e_level0_row2" class="row_heading level0 row2" ></th>
#       <td id="T_b4f1e_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_b4f1e_row2_col1" class="data row2 col1" >Rp 1600000.00</td>
#       <td id="T_b4f1e_row2_col2" class="data row2 col2" >Rp 190000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b4f1e_level0_row3" class="row_heading level0 row3" ></th>
#       <td id="T_b4f1e_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_b4f1e_row3_col1" class="data row3 col1" >Rp 600000.00</td>
#       <td id="T_b4f1e_row3_col2" class="data row3 col2" >Rp 10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_b4f1e_level0_row4" class="row_heading level0 row4" ></th>
#       <td id="T_b4f1e_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_b4f1e_row4_col1" class="data row4 col1" >Rp 1400000.00</td>
#       <td id="T_b4f1e_row4_col2" class="data row4 col2" >Rp 10000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menambahkan judul/caption ke Styler
laporan.set_caption('Data Omset dan Operasional')

# Memberikan caption atau judul pada tampilan Styler untuk memberikan konteks atau informasi tambahan.
# Out:
# <style type="text/css">
# </style>
# <table id="T_f35c4">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f35c4_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_f35c4_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_f35c4_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f35c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f35c4_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_f35c4_row0_col1" class="data row0 col1" >Rp 900000.00</td>
#       <td id="T_f35c4_row0_col2" class="data row0 col2" >Rp 160000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f35c4_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_f35c4_row1_col1" class="data row1 col1" >Rp 1000000.00</td>
#       <td id="T_f35c4_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f35c4_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_f35c4_row2_col1" class="data row2 col1" >Rp 1600000.00</td>
#       <td id="T_f35c4_row2_col2" class="data row2 col2" >Rp 190000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f35c4_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_f35c4_row3_col1" class="data row3 col1" >Rp 600000.00</td>
#       <td id="T_f35c4_row3_col2" class="data row3 col2" >Rp 10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f35c4_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_f35c4_row4_col1" class="data row4 col1" >Rp 1400000.00</td>
#       <td id="T_f35c4_row4_col2" class="data row4 col2" >Rp 10000.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Menyoroti nilai minimum dan maksimum pada kolom 'omset' dengan warna berbeda
laporan.highlight_min('omset', color='pink')
laporan.highlight_max('omset', color='lightgreen')

# Menyoroti nilai minimum dan maksimum pada kolom 'operasional' dengan warna berbeda
laporan.highlight_min('operasional', color='lightblue')
laporan.highlight_max('operasional', color='grey')

# Menyajikan tampilan yang diberi sorotan untuk memvisualisasikan nilai minimum dan maksimum pada data omset dan operasional.
# Out:
# <style type="text/css">
# #T_f35c4_row2_col1 {
#   background-color: lightgreen;
# }
# #T_f35c4_row2_col2 {
#   background-color: grey;
# }
# #T_f35c4_row3_col1 {
#   background-color: pink;
# }
# #T_f35c4_row3_col2, #T_f35c4_row4_col2 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_f35c4">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f35c4_level0_col0" class="col_heading level0 col0" >tanggal</th>
#       <th id="T_f35c4_level0_col1" class="col_heading level0 col1" >omset</th>
#       <th id="T_f35c4_level0_col2" class="col_heading level0 col2" >operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f35c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f35c4_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_f35c4_row0_col1" class="data row0 col1" >Rp 900000.00</td>
#       <td id="T_f35c4_row0_col2" class="data row0 col2" >Rp 160000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f35c4_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_f35c4_row1_col1" class="data row1 col1" >Rp 1000000.00</td>
#       <td id="T_f35c4_row1_col2" class="data row1 col2" >Rp 80000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f35c4_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_f35c4_row2_col1" class="data row2 col1" >Rp 1600000.00</td>
#       <td id="T_f35c4_row2_col2" class="data row2 col2" >Rp 190000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f35c4_row3_col0" class="data row3 col0" >04/01/00</td>
#       <td id="T_f35c4_row3_col1" class="data row3 col1" >Rp 600000.00</td>
#       <td id="T_f35c4_row3_col2" class="data row3 col2" >Rp 10000.00</td>
#     </tr>
#     <tr>
#       <th id="T_f35c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f35c4_row4_col0" class="data row4 col0" >05/01/00</td>
#       <td id="T_f35c4_row4_col1" class="data row4 col1" >Rp 1400000.00</td>
#       <td id="T_f35c4_row4_col2" class="data row4 col2" >Rp 10000.00</td>
#     </tr>
#   </tbody>
# </table>
